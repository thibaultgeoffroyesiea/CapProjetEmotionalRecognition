# %% [markdown]
# - https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html#sklearn.naive_bayes.MultinomialNB
# -

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML_loader import DatasetLoader,ModelLoader

# %%
#Get data 
loader = DatasetLoader()
loader.read_dataset('./features_resnet.csv',class_path='labelsDefault.txt',separator=',')
#loader.read_dataset('./partial_database.csv',class_path='labelsDefault.txt',separator=',')
loader.add_dataset(file_path='./partial_database.csv')
loader.split_dataset()

#Normalize data, if not already normalized
print(np.shape(loader.X_train),np.shape(loader.X_test),np.shape(loader.y_train),np.shape(loader.y_test))
# Out:
#     AU01_r   AU02_r   AU04_r   AU05_r   AU06_r   AU07_r   AU09_r   AU10_r  \
# 0     0.00     0.00     0.28      0.0     0.31     1.19      0.0     0.26
# 1     0.73     0.22     0.55      0.0     0.36     0.68      0.0     0.89
# 2     0.66     0.22     1.48      0.0     0.45     0.44      0.0     0.81
# 3     0.25     0.00     1.52      0.0     0.35     0.24      0.0     0.33
# 4     0.00     0.00     1.71      0.0     0.24     0.31      0.0     0.36
#
#     AU12_r   AU14_r   AU15_r   AU17_r   AU20_r   AU23_r   AU25_r   AU26_r  \
# 0     0.10     0.00     0.71     0.89     0.00     0.00     0.00     0.82
# 1     0.39     0.05     0.46     1.47     0.00     0.00     0.56     1.04
# 2     0.36     0.07     0.22     2.36     0.11     0.51     0.56     1.25
# 3     0.19     0.07     0.60     2.14     0.11     0.51     0.42     0.84
# 4     0.25     0.02     0.38     1.89     0.11     0.51     0.05     0.58
#
#     AU45_r
# 0     0.00
# 1     0.17
# 2     0.87
# 3     0.87
# 4     0.69
#           0         1         2         3         4         5         6  \
# 0  0.058971  0.626277  0.107093  0.670639  0.685376  0.672881  0.541003
# 1  0.293999  0.680076  0.070964  0.704674  0.800976  0.759914  0.789037
# 2  0.026243  0.493064  0.071549  0.598101  0.668996  0.798525  0.383728
# 3  0.264287  0.605679  0.043540  0.597128  0.845713  0.770380  0.757597
# 4  0.049339  0.610061  0.145537  0.661091  0.692952  0.739890  0.485597
#
#           7         8         9  ...   AU10_r   AU12_r   AU14_r   AU15_r  \
# 0  0.021652  0.078406  0.713660  ...     0.26     0.10     0.00     0.71
# 1  0.083484  0.022216  0.857469  ...     0.89     0.39     0.05     0.46
# 2  0.031116  0.151202  0.682578  ...     0.81     0.36     0.07     0.22
# 3  0.022491  0.014760  0.863484  ...     0.33     0.19     0.07     0.60
# 4  0.096431  0.157701  0.787261  ...     0.36     0.25     0.02     0.38
#
#     AU17_r   AU20_r   AU23_r   AU25_r   AU26_r   AU45_r
# 0     0.89     0.00     0.00     0.00     0.82     0.00
# 1     1.47     0.00     0.00     0.56     1.04     0.17
# 2     2.36     0.11     0.51     0.56     1.25     0.87
# 3     2.14     0.11     0.51     0.42     0.84     0.87
# 4     1.89     0.11     0.51     0.05     0.58     0.69
#
# [5 rows x 273 columns]
# (4048, 273) (1012, 273) (4048,) (1012,)

# %%
#Get model
model = ModelLoader()
model.set_model(MultinomialNB())

cv = RepeatedStratifiedKFold(n_splits=22, n_repeats=3, random_state=1)

#Optimization 
param = {'alpha': np.linspace(0.5, 1.5, 6),
            'fit_prior': [True, False]}

model.set_optimal_params(param)

model.optimize(loader.X_train,loader.y_train,cv=cv,scoring='accuracy',n_iter=10)

#Train model with optimal params
model.set_model(MultinomialNB(**model.optimal_params))

# %%
##Split by class, to increment by class:
class_to_group = {1:[1,2,3,4,5,6,7],2:[8,9],3:[10,11,12,13],4:[14,15,16],5:[17,18],6:[19],7:[20,21,22]}
X_train_merged, X_test_merged, y_train_merged, y_test_merged=loader.split_dataset_class(class_to_group,random_state=1)
memory_values = []
accuracy_learned_grouped = []


#Train model
for idx,(X_train,y_train,X_test,y_test) in enumerate(zip(X_train_merged,y_train_merged,X_test_merged,y_test_merged)):
    mem,res=model.partial_fit_train(X_train,y_train,classes=loader.classes)
    print(f"Score accuracy group {idx}: ",model.score(X_test,y_test))
    accuracy_learned = []
    for i in range(idx+1):
        print(f"Score accuracy group learned {i}: ",model.score(X_test_merged[i],y_test_merged[i]))
        accuracy_learned.append(model.score(X_test_merged[i],y_test_merged[i]))
    print("Score accuracy global: ",model.score(loader.X_test,loader.y_test))
    print("Memory: ",np.mean(mem),"MB")
    memory_values.append(np.mean(mem))
    accuracy_learned_grouped.append(accuracy_learned)
    y_pred=model.predict(loader.X_test)
    cm = confusion_matrix(loader.y_test, y_pred)
    ConfusionMatrixDisplay(confusion_matrix=cm).plot()

model.reset_model()

average_memory = np.mean(memory_values)
print("Average memory usage: ", average_memory,"MB")
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.058971  0.626277  0.107093  0.670639  0.685376  0.672881  0.541003
# 1  0.293999  0.680076  0.070964  0.704674  0.800976  0.759914  0.789037
# 2  0.026243  0.493064  0.071549  0.598101  0.668996  0.798525  0.383728
# 3  0.264287  0.605679  0.043540  0.597128  0.845713  0.770380  0.757597
# 4  0.049339  0.610061  0.145537  0.661091  0.692952  0.739890  0.485597
#
#           7         8         9  ...   AU12_r   AU14_r   AU15_r   AU17_r  \
# 0  0.021652  0.078406  0.713660  ...     0.10     0.00     0.71     0.89
# 1  0.083484  0.022216  0.857469  ...     0.39     0.05     0.46     1.47
# 2  0.031116  0.151202  0.682578  ...     0.36     0.07     0.22     2.36
# 3  0.022491  0.014760  0.863484  ...     0.19     0.07     0.60     2.14
# 4  0.096431  0.157701  0.787261  ...     0.25     0.02     0.38     1.89
#
#     AU20_r   AU23_r   AU25_r   AU26_r   AU45_r  class
# 0     0.00     0.00     0.00     0.82     0.00      1
# 1     0.00     0.00     0.56     1.04     0.17      1
# 2     0.11     0.51     0.56     1.25     0.87      1
# 3     0.11     0.51     0.42     0.84     0.87      1
# 4     0.11     0.51     0.05     0.58     0.69      1
#
# [5 rows x 274 columns]
#              0         1         2         3         4         5         6  \
# 1610  0.310142  0.801380  0.356934  0.052466  1.267476  0.865366  0.069772
# 1611  0.168871  0.353946  0.161879  0.032091  0.610716  0.473272  0.042687
# 1612  0.281168  0.257956  0.085129  0.023575  0.741044  0.552327  0.065450
# 1613  0.304899  0.472891  0.115382  0.050010  0.450385  0.235422  0.081646
# 1614  0.317133  0.291713  0.076116  0.034237  0.569784  0.394309  0.106810
#
#              7         8         9  ...   AU12_r   AU14_r   AU15_r   AU17_r  \
#
# 4374  0.330724  0.000000  0.017491  0.407674  0.081284  0.291560  0.244524
#
#              7         8         9  ...   AU12_r   AU14_r   AU15_r   AU17_r  \
# 4370  0.881272  0.208489  0.172324  ...     1.02     0.77     0.43     3.67
# 4371  0.876261  0.304592  0.099534  ...     0.56     0.99     0.88     2.97
# 4372  0.959037  0.418166  0.032551  ...     0.16     0.22     1.43     3.33
# 4373  0.596009  0.318213  0.038550  ...     0.07     0.21     1.30     3.64
# 4374  0.533197  0.211610  0.024138  ...     0.07     0.00     1.50     3.97
#
#        AU20_r   AU23_r   AU25_r   AU26_r   AU45_r  class
# 4370     0.05     1.12     0.40     0.57     0.00     20
# 4371     0.00     0.16     0.44     0.57     0.16     20
# 4372     0.00     0.00     0.47     1.07     0.16     20
# 4373     0.00     0.22     0.07     0.50     0.21     20
# 4374     0.18     0.29     0.04     0.50     0.05     20
#
# [5 rows x 274 columns]
# Partial fit
# Score accuracy group 0:  0.968944099378882
# Score accuracy group learned 0:  0.968944099378882
# Score accuracy global:  0.3201581027667984
# Memory:  411.2109375 MB
# Partial fit
# Score accuracy group 1:  0.782608695652174
# Score accuracy group learned 0:  0.9596273291925466
# Score accuracy group learned 1:  0.782608695652174
# Score accuracy global:  0.4051383399209486
# Memory:  415.1953125 MB
# Partial fit
# Score accuracy group 2:  0.6032608695652174
# Score accuracy group learned 0:  0.906832298136646
# Score accuracy group learned 1:  0.7717391304347826
# Score accuracy group learned 2:  0.6032608695652174
# Score accuracy global:  0.4901185770750988
# Memory:  388.765625 MB
# Partial fit
# Score accuracy group 3:  0.427536231884058
# Score accuracy group learned 0:  0.860248447204969
# Score accuracy group learned 1:  0.7608695652173914
# Score accuracy group learned 2:  0.47282608695652173
# Score accuracy group learned 3:  0.427536231884058
# Score accuracy global:  0.5138339920948617
# Memory:  390.6796875 MB
# Partial fit
# Score accuracy group 4:  0.41304347826086957
# Score accuracy group learned 0:  0.84472049689441
# Score accuracy group learned 1:  0.7608695652173914
# Score accuracy group learned 2:  0.40217391304347827
# Score accuracy group learned 3:  0.41304347826086957
# Score accuracy group learned 4:  0.41304347826086957
# Score accuracy global:  0.5573122529644269
# Memory:  391.99609375 MB
# Partial fit
# Score accuracy group 5:  0.717391304347826
# Score accuracy group learned 0:  0.8416149068322981
# Score accuracy group learned 1:  0.7608695652173914
# Score accuracy group learned 2:  0.3804347826086957
# Score accuracy group learned 3:  0.41304347826086957
# Score accuracy group learned 4:  0.41304347826086957
# Score accuracy group learned 5:  0.717391304347826
# Score accuracy global:  0.5820158102766798
# Memory:  393.73828125 MB
# Partial fit
# Score accuracy group 6:  0.16666666666666666
# Score accuracy group learned 0:  0.8354037267080745
# Score accuracy group learned 1:  0.7608695652173914
# Score accuracy group learned 2:  0.3695652173913043
# Score accuracy group learned 3:  0.37681159420289856
# Score accuracy group learned 4:  0.31521739130434784
# Score accuracy group learned 5:  0.717391304347826
# Score accuracy group learned 6:  0.16666666666666666
# Score accuracy global:  0.5958498023715415
# Memory:  394.75390625 MB
# Average memory usage:  398.04854910714283 MB

# %%
#Figure for accuracy on learned class
df = pd.DataFrame(accuracy_learned_grouped)
df1 = df.replace(np.nan, 0)
df=df.T

fig, ax = plt.subplots()
for i in range(len(class_to_group)):
    ax.plot(list(df.iloc[i]),label=f'Group {i+1}')

ax.set(xlabel='Number of learned groups', ylabel='Accuracy',
        title='Accuracy on learned groups')

ax.grid()
ax.legend()
plt.show()

# Bar plot 
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.set(xlabel='Number of learned groups', ylabel='Accuracy',
        title='Accuracy on learned groups')

df1.plot(kind='bar', ax=ax)
# Out:
# <Axes: title={'center': 'Accuracy on learned groups'}, xlabel='Number of learned groups', ylabel='Accuracy'>

# %%
X_train_split_data,y_train_split_data,X_test_split_data,y_test_split_data=loader.split_dataset_data(10,random_state=1)
memory_values = []

for x in range(len(X_train_split_data)):
    mem,res=model.partial_fit_train(X_train_split_data[x],y_train_split_data[x],classes=loader.classes)
    print(f"Score accuracy batch {x}: ",model.score(X_test_split_data[x],y_test_split_data[x]))
    print("Score accuracy global: ",model.score(loader.X_test,loader.y_test))
    print("Memory: ",np.mean(mem),"MB")
    memory_values.append(np.mean(mem))

    y_pred=model.predict(loader.X_test)
    cm = confusion_matrix(loader.y_test, y_pred)
    ConfusionMatrixDisplay(confusion_matrix=cm).plot()

model.reset_model()

average_memory = np.mean(memory_values)
print("Average memory usage: ", average_memory,"MB")
# Out:
# Partial fit
# Score accuracy batch 0:  0.5375494071146245
# Score accuracy global:  0.5938735177865613
# Memory:  408.68515625 MB
# Partial fit
# Score accuracy batch 1:  0.5770750988142292
# Score accuracy global:  0.591897233201581
# Memory:  410.67890625 MB
# Partial fit
# Score accuracy batch 2:  0.5770750988142292
# Score accuracy global:  0.5928853754940712
# Memory:  395.812667932243 MB
# Partial fit
# Score accuracy batch 3:  0.5790513833992095
# Score accuracy global:  0.5938735177865613
# Memory:  396.0109375 MB
# Partial fit
# Score accuracy batch 4:  0.575098814229249
# Score accuracy global:  0.5938735177865613
# Memory:  397.03828125 MB
# Partial fit
# Score accuracy batch 5:  0.5691699604743083
# Score accuracy global:  0.5928853754940712
# Memory:  398.4484375 MB
# Partial fit
# Score accuracy batch 6:  0.567193675889328
# Score accuracy global:  0.5938735177865613
# Memory:  399.925 MB
# Partial fit
# Score accuracy batch 7:  0.5573122529644269
# Score accuracy global:  0.5948616600790514
# Memory:  402.375415415952 MB
# Partial fit
# Score accuracy batch 8:  0.5770750988142292
# Score accuracy global:  0.591897233201581
# Memory:  403.8108425946303 MB
# Partial fit
# Score accuracy batch 9:  0.5889328063241107
# Score accuracy global:  0.5938735177865613
# Memory:  403.9 MB
# Average memory usage:  401.66856446928256 MB
